# %% [markdown]
# # Read & Plot Time Series Data

# %%
import pandas as pd
import datetime as dt
import numpy as np
from sklearn.metrics import mean_squared_error
from math import sqrt
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 15, 6
from patsy import dmatrices
from pandas import Series
from matplotlib import pyplot
from datetime import datetime
from matplotlib.pyplot import figure
#figure(num=None, figsize=(8, 6), dpi=80, facecolor='w', edgecolor='k')

# %% [markdown]
# # Read yearly time series: USGDP

# %%
USGDP = pd.read_csv('GDPUS.csv', header=0)
USGDP.head(8)
# Out:
#    Year    GDP
# 0  1929  821.8
# 1  1930  748.9
# 2  1931  691.3
# 3  1932  599.7
# 4  1933  587.1
# 5  1934  632.6
# 6  1935  681.6
# 7  1936  777.9

# %%
USGDP.tail(5)
# Out:
#     Year     GDP
# 58  1987  4718.6
# 59  1988  4784.6
# 60  1989  4739.2
# 61  1990  4822.3
# 62  1991  4835.0

# %%
date_rng = pd.date_range(start='1/1/1929', end='31/12/1991', freq='Y')
date_rng
# Out:
# DatetimeIndex(['1929-12-31', '1930-12-31', '1931-12-31', '1932-12-31',
#                '1933-12-31', '1934-12-31', '1935-12-31', '1936-12-31',
#                '1937-12-31', '1938-12-31', '1939-12-31', '1940-12-31',
#                '1941-12-31', '1942-12-31', '1943-12-31', '1944-12-31',
#                '1945-12-31', '1946-12-31', '1947-12-31', '1948-12-31',
#                '1949-12-31', '1950-12-31', '1951-12-31', '1952-12-31',
#                '1953-12-31', '1954-12-31', '1955-12-31', '1956-12-31',
#                '1957-12-31', '1958-12-31', '1959-12-31', '1960-12-31',
#                '1961-12-31', '1962-12-31', '1963-12-31', '1964-12-31',
#                '1965-12-31', '1966-12-31', '1967-12-31', '1968-12-31',
#                '1969-12-31', '1970-12-31', '1971-12-31', '1972-12-31',
#                '1973-12-31', '1974-12-31', '1975-12-31', '1976-12-31',
#                '1977-12-31', '1978-12-31', '1979-12-31', '1980-12-31',
# ...

# %%
USGDP['TimeIndex'] = pd.DataFrame(date_rng, columns=['Year'])
USGDP.head(8)
# Out:
#    Year    GDP  TimeIndex
# 0  1929  821.8 1929-12-31
# 1  1930  748.9 1930-12-31
# 2  1931  691.3 1931-12-31
# 3  1932  599.7 1932-12-31
# 4  1933  587.1 1933-12-31
# 5  1934  632.6 1934-12-31
# 6  1935  681.6 1935-12-31
# 7  1936  777.9 1936-12-31

# %%
plt.plot(USGDP.TimeIndex, USGDP.GDP)
plt.legend(loc='best')
#pyplot.show()

# %% [markdown]
# # Task 1: Read GDP India series

# %%
GDPIND = pd.read_csv('GDPIndia.csv', header=0)
GDPIND.head()
# Out:
#    Year  GDPpercapita
# 0  1960     81.284764
# 1  1961     84.426437
# 2  1962     88.914919
# 3  1963    100.048592
# 4  1964    114.315161

# %%
GDPIND.tail()
# Out:
#     Year  GDPpercapita
# 53  2013   1452.195373
# 54  2014   1576.004018
# 55  2015   1606.038285
# 56  2016   1717.473878
# 57  2017   1939.612984

# %%
date_rng1 = pd.date_range(start='1/1/1960', end='31/12/2017', freq='Y')
date_rng1
# Out:
# DatetimeIndex(['1960-12-31', '1961-12-31', '1962-12-31', '1963-12-31',
#                '1964-12-31', '1965-12-31', '1966-12-31', '1967-12-31',
#                '1968-12-31', '1969-12-31', '1970-12-31', '1971-12-31',
#                '1972-12-31', '1973-12-31', '1974-12-31', '1975-12-31',
#                '1976-12-31', '1977-12-31', '1978-12-31', '1979-12-31',
#                '1980-12-31', '1981-12-31', '1982-12-31', '1983-12-31',
#                '1984-12-31', '1985-12-31', '1986-12-31', '1987-12-31',
#                '1988-12-31', '1989-12-31', '1990-12-31', '1991-12-31',
#                '1992-12-31', '1993-12-31', '1994-12-31', '1995-12-31',
#                '1996-12-31', '1997-12-31', '1998-12-31', '1999-12-31',
#                '2000-12-31', '2001-12-31', '2002-12-31', '2003-12-31',
#                '2004-12-31', '2005-12-31', '2006-12-31', '2007-12-31',
#                '2008-12-31', '2009-12-31', '2010-12-31', '2011-12-31',
# ...

# %%
GDPIND['TimeIndex'] = pd.DataFrame(date_rng1, columns=['Year'])
GDPIND.head(8)
# Out:
#    Year  GDPpercapita  TimeIndex
# 0  1960     81.284764 1960-12-31
# 1  1961     84.426437 1961-12-31
# 2  1962     88.914919 1962-12-31
# 3  1963    100.048592 1963-12-31
# 4  1964    114.315161 1964-12-31
# 5  1965    118.063382 1965-12-31
# 6  1966     89.053583 1966-12-31
# 7  1967     95.330783 1967-12-31

# %%
plt.plot(GDPIND.TimeIndex, GDPIND.GDPpercapita)
plt.legend(loc='best')
#pyplot.show()

# %% [markdown]
# # Task 2: Read English Daily Wage series

# %%
ENGWAGE = pd.read_csv('EngWage.csv', header=0)
ENGWAGE.head()
# Out:
#    Year  DailyWage
# 0  1950      24.27
# 1  1951      24.17
# 2  1952      23.76
# 3  1953      24.17
# 4  1954      25.18

# %%
ENGWAGE.tail()
# Out:
#     Year  DailyWage
# 40  1990      46.19
# 41  1991      46.86
# 42  1992      49.42
# 43  1993      49.51
# 44  1994      49.99

# %%
date_rng2 = pd.date_range(start='1/1/1950', end='31/12/1994', freq='Y')
date_rng2
# Out:
# DatetimeIndex(['1950-12-31', '1951-12-31', '1952-12-31', '1953-12-31',
#                '1954-12-31', '1955-12-31', '1956-12-31', '1957-12-31',
#                '1958-12-31', '1959-12-31', '1960-12-31', '1961-12-31',
#                '1962-12-31', '1963-12-31', '1964-12-31', '1965-12-31',
#                '1966-12-31', '1967-12-31', '1968-12-31', '1969-12-31',
#                '1970-12-31', '1971-12-31', '1972-12-31', '1973-12-31',
#                '1974-12-31', '1975-12-31', '1976-12-31', '1977-12-31',
#                '1978-12-31', '1979-12-31', '1980-12-31', '1981-12-31',
#                '1982-12-31', '1983-12-31', '1984-12-31', '1985-12-31',
#                '1986-12-31', '1987-12-31', '1988-12-31', '1989-12-31',
#                '1990-12-31', '1991-12-31', '1992-12-31', '1993-12-31',
#                '1994-12-31'],
#               dtype='datetime64[ns]', freq='A-DEC')

# %%
ENGWAGE['TimeIndex'] = pd.DataFrame(date_rng2, columns=['Year'])
ENGWAGE.head(8)
# Out:
#    Year  DailyWage  TimeIndex
# 0  1950      24.27 1950-12-31
# 1  1951      24.17 1951-12-31
# 2  1952      23.76 1952-12-31
# 3  1953      24.17 1953-12-31
# 4  1954      25.18 1954-12-31
# 5  1955      25.74 1955-12-31
# 6  1956      26.19 1956-12-31
# 7  1957      26.68 1957-12-31

# %%
plt.plot(ENGWAGE.TimeIndex, ENGWAGE.DailyWage)
plt.legend(loc='best')
#pyplot.show()

# %% [markdown]
# # Read Quarterly Time Series: Retail Turnover

# %%
Turnover = pd.read_csv('RetailTurnover.csv')
#Turnover.head()

# %%
from datetime import datetime
date_rng = pd.date_range(start='7/1/1982', end='31/3/1992', freq='Q')

# %%
date_rng
# Out:
# DatetimeIndex(['1982-09-30', '1982-12-31', '1983-03-31', '1983-06-30',
#                '1983-09-30', '1983-12-31', '1984-03-31', '1984-06-30',
#                '1984-09-30', '1984-12-31', '1985-03-31', '1985-06-30',
#                '1985-09-30', '1985-12-31', '1986-03-31', '1986-06-30',
#                '1986-09-30', '1986-12-31', '1987-03-31', '1987-06-30',
#                '1987-09-30', '1987-12-31', '1988-03-31', '1988-06-30',
#                '1988-09-30', '1988-12-31', '1989-03-31', '1989-06-30',
#                '1989-09-30', '1989-12-31', '1990-03-31', '1990-06-30',
#                '1990-09-30', '1990-12-31', '1991-03-31', '1991-06-30',
#                '1991-09-30', '1991-12-31', '1992-03-31'],
#               dtype='datetime64[ns]', freq='Q-DEC')

# %%
Turnover['TimeIndex'] = pd.DataFrame(date_rng, columns=['Quarter'])
Turnover.head()
# Out:
#    Year Quarter  Turnover  TimeIndex
# 0  1982      Q3   13423.2 1982-09-30
# 1  1982      Q4   13128.8 1982-12-31
# 2  1983      Q1   15398.8 1983-03-31
# 3  1983      Q2   12964.2 1983-06-30
# 4  1983      Q3   13133.5 1983-09-30

# %%
plt.plot(Turnover.TimeIndex, Turnover.Turnover)
plt.legend(loc='best')
pyplot.show()

# %% [markdown]
# # Task 3: Read Portugal Port Series

# %%
Portugal = pd.read_csv('PortugalPort.csv')
Portugal.head()
# Out:
#    Year Quarter  Pax
# 0  2000      Q1   21
# 1  2000      Q2   61
# 2  2000      Q3  119
# 3  2000      Q4   30
# 4  2001      Q1   16

# %%
Portugal.tail()
# Out:
#     Year Quarter  Pax
# 67  2016      Q4   54
# 68  2017      Q1   29
# 69  2017      Q2   96
# 70  2017      Q3  152
# 71  2017      Q4   61

# %%
from datetime import datetime
date_rng4 = pd.date_range(start='1/3/2000', end='31/12/2017', freq='Q')
date_rng4
# Out:
# DatetimeIndex(['2000-03-31', '2000-06-30', '2000-09-30', '2000-12-31',
#                '2001-03-31', '2001-06-30', '2001-09-30', '2001-12-31',
#                '2002-03-31', '2002-06-30', '2002-09-30', '2002-12-31',
#                '2003-03-31', '2003-06-30', '2003-09-30', '2003-12-31',
#                '2004-03-31', '2004-06-30', '2004-09-30', '2004-12-31',
#                '2005-03-31', '2005-06-30', '2005-09-30', '2005-12-31',
#                '2006-03-31', '2006-06-30', '2006-09-30', '2006-12-31',
#                '2007-03-31', '2007-06-30', '2007-09-30', '2007-12-31',
#                '2008-03-31', '2008-06-30', '2008-09-30', '2008-12-31',
#                '2009-03-31', '2009-06-30', '2009-09-30', '2009-12-31',
#                '2010-03-31', '2010-06-30', '2010-09-30', '2010-12-31',
#                '2011-03-31', '2011-06-30', '2011-09-30', '2011-12-31',
#                '2012-03-31', '2012-06-30', '2012-09-30', '2012-12-31',
# ...

# %%
Portugal['TimeIndex'] = pd.DataFrame(date_rng4, columns=['Quarter'])
Portugal.head()
# Out:
#    Year Quarter  Pax  TimeIndex
# 0  2000      Q1   21 2000-03-31
# 1  2000      Q2   61 2000-06-30
# 2  2000      Q3  119 2000-09-30
# 3  2000      Q4   30 2000-12-31
# 4  2001      Q1   16 2001-03-31

# %%
plt.plot(Portugal.TimeIndex, Portugal.Pax)
plt.legend(loc='best')
pyplot.show()

# %% [markdown]
# # Task 4: Read Petrol Consumption Series

# %%
Petrol = pd.read_csv('Petrol.csv')
Petrol.head()
# Out:
#    Year Quarter  Consumption
# 0  2001      Q1       14.978
# 1  2001      Q2       11.099
# 2  2001      Q3       10.057
# 3  2001      Q4       10.454
# 4  2002      Q1        9.295

# %%
Petrol.tail()
# Out:
#     Year Quarter  Consumption
# 46  2012      Q3      0.88818
# 47  2012      Q4      0.99804
# 48  2013      Q1      0.84120
# 49  2013      Q2      0.74032
# 50  2013      Q3      0.72823

# %%
from datetime import datetime
date_rng5 = pd.date_range(start='1/3/2001', end='31/10/2013', freq='Q')
date_rng5
# Out:
# DatetimeIndex(['2001-03-31', '2001-06-30', '2001-09-30', '2001-12-31',
#                '2002-03-31', '2002-06-30', '2002-09-30', '2002-12-31',
#                '2003-03-31', '2003-06-30', '2003-09-30', '2003-12-31',
#                '2004-03-31', '2004-06-30', '2004-09-30', '2004-12-31',
#                '2005-03-31', '2005-06-30', '2005-09-30', '2005-12-31',
#                '2006-03-31', '2006-06-30', '2006-09-30', '2006-12-31',
#                '2007-03-31', '2007-06-30', '2007-09-30', '2007-12-31',
#                '2008-03-31', '2008-06-30', '2008-09-30', '2008-12-31',
#                '2009-03-31', '2009-06-30', '2009-09-30', '2009-12-31',
#                '2010-03-31', '2010-06-30', '2010-09-30', '2010-12-31',
#                '2011-03-31', '2011-06-30', '2011-09-30', '2011-12-31',
#                '2012-03-31', '2012-06-30', '2012-09-30', '2012-12-31',
#                '2013-03-31', '2013-06-30', '2013-09-30'],
#               dtype='datetime64[ns]', freq='Q-DEC')

# %%
Petrol['TimeIndex'] = pd.DataFrame(date_rng5, columns=['Quarter'])
Petrol.head()
# Out:
#    Year Quarter  Consumption  TimeIndex
# 0  2001      Q1       14.978 2001-03-31
# 1  2001      Q2       11.099 2001-06-30
# 2  2001      Q3       10.057 2001-09-30
# 3  2001      Q4       10.454 2001-12-31
# 4  2002      Q1        9.295 2002-03-31

# %%
plt.plot(Petrol.TimeIndex, Petrol.Consumption)
plt.legend(loc='best')
pyplot.show()

# %% [markdown]
# # Read Monthly Time Series: Average Monthly Temperature

# %%
AirTemp = pd.read_csv('AirTemp.csv')
#AirTemp.head()

# %%
date_rng = pd.date_range(start='1/1/1920', end='31/12/1939', freq='M')
#date_rng

# %%
AirTemp['TimeIndex'] = pd.DataFrame(date_rng, columns=['Month'])
AirTemp.head()
# Out:
#    Year Month  AvgTemp  TimeIndex
# 0  1920   Jan     40.6 1920-01-31
# 1  1920   Feb     40.8 1920-02-29
# 2  1920   Mar     44.4 1920-03-31
# 3  1920   Apr     46.7 1920-04-30
# 4  1920   May     54.1 1920-05-31

# %%
plt.plot(AirTemp.TimeIndex, AirTemp.AvgTemp)
plt.legend(loc='best')
pyplot.show()

# %% [markdown]
# # Task 5: Read Champagne Series

# %%
Champagne = pd.read_csv('Champagne.csv')
Champagne.head()
# Out:
#    Year Month  Sales
# 0  1964   Jan   2815
# 1  1964   Feb   2672
# 2  1964   Mar   2755
# 3  1964   Apr   2721
# 4  1964   May   2946

# %%
Champagne.tail()
# Out:
#      Year Month  Sales
# 100  1972   May   4618
# 101  1972   Jun   5312
# 102  1972   Jul   4298
# 103  1972   Aug   1413
# 104  1972   Sep   5877

# %%
date_rng6 = pd.date_range(start='1/1/1964', end='31/12/1972', freq='M')
date_rng6
# Out:
# DatetimeIndex(['1964-01-31', '1964-02-29', '1964-03-31', '1964-04-30',
#                '1964-05-31', '1964-06-30', '1964-07-31', '1964-08-31',
#                '1964-09-30', '1964-10-31',
#                ...
#                '1972-03-31', '1972-04-30', '1972-05-31', '1972-06-30',
#                '1972-07-31', '1972-08-31', '1972-09-30', '1972-10-31',
#                '1972-11-30', '1972-12-31'],
#               dtype='datetime64[ns]', length=108, freq='M')

# %%
Champagne['TimeIndex'] = pd.DataFrame(date_rng6, columns=['Month'])
Champagne.head(20)
# Out:
#     Year Month  Sales  TimeIndex
# 0   1964   Jan   2815 1964-01-31
# 1   1964   Feb   2672 1964-02-29
# 2   1964   Mar   2755 1964-03-31
# 3   1964   Apr   2721 1964-04-30
# 4   1964   May   2946 1964-05-31
# 5   1964   Jun   3036 1964-06-30
# 6   1964   Jul   2282 1964-07-31
# 7   1964   Aug   2212 1964-08-31
# 8   1964   Sep   2922 1964-09-30
# 9   1964   Oct   4301 1964-10-31
# 10  1964   Nov   5764 1964-11-30
# 11  1964   Dec   7312 1964-12-31
# 12  1965   Jan   2541 1965-01-31
# 13  1965   Feb   2475 1965-02-28
# 14  1965   Mar   3031 1965-03-31
# 15  1965   Apr   3266 1965-04-30
# 16  1965   May   3776 1965-05-31
# 17  1965   Jun   3230 1965-06-30
# 18  1965   Jul   3028 1965-07-31
# 19  1965   Aug   1759 1965-08-31

# %%
plt.plot(Champagne.TimeIndex, Champagne.Sales)
plt.legend(loc='best')
pyplot.show()

# %% [markdown]
# # Task 6: Read International Air Passengers Data

# %%
AirPax = pd.read_csv('AirPax.csv')
AirPax.head()
# Out:
#    Year Month  Pax
# 0  1949   Jan  112
# 1  1949   Feb  118
# 2  1949   Mar  132
# 3  1949   Apr  129
# 4  1949   May  121

# %%
AirPax.tail()
# Out:
#      Year Month  Pax
# 139  1960   Aug  606
# 140  1960   Sep  508
# 141  1960   Oct  461
# 142  1960   Nov  390
# 143  1960   Dec  432

# %%
date_rng7 = pd.date_range(start='1/1/1949', end='31/12/1960', freq='M')
#date_rng7

# %%
AirPax['TimeIndex'] = pd.DataFrame(date_rng7, columns=['Month'])
AirPax.head()
# Out:
#    Year Month  Pax  TimeIndex
# 0  1949   Jan  112 1949-01-31
# 1  1949   Feb  118 1949-02-28
# 2  1949   Mar  132 1949-03-31
# 3  1949   Apr  129 1949-04-30
# 4  1949   May  121 1949-05-31

# %%
plt.plot(AirPax.TimeIndex, AirPax.Pax)
plt.legend(loc='best')
pyplot.show()

# %% [markdown]
# # Read Tractor Sales Series

# %%
Tractor = pd.read_csv("TractorSales.csv")
Tractor.head(5)
# Out:
#   Month-Year  Number of Tractor Sold
# 0      3-Jan                     141
# 1      3-Feb                     157
# 2      3-Mar                     185
# 3      3-Apr                     199
# 4      3-May                     203

# %%
dates = pd.date_range(start='2003-01-01', freq='MS', periods=len(Tractor))

# %%
import calendar
Tractor['Month'] = dates.month
Tractor['Month'] = Tractor['Month'].apply(lambda x: calendar.month_abbr[x])
Tractor['Year'] = dates.year

# %%
#Tractor.drop(['Month-Year'], axis=1, inplace=True)
Tractor.rename(columns={'Number of Tractor Sold':'Tractor-Sales'}, inplace=True)
Tractor = Tractor[['Month', 'Year', 'Tractor-Sales']]

# %%
Tractor.set_index(dates, inplace=True)

# %%
Tractor.head(5)
# Out:
#            Month  Year  Tractor-Sales
# 2003-01-01   Jan  2003            141
# 2003-02-01   Feb  2003            157
# 2003-03-01   Mar  2003            185
# 2003-04-01   Apr  2003            199
# 2003-05-01   May  2003            203

# %%
# extract out the time-series
sales_ts = Tractor['Tractor-Sales']

# %%
plt.figure(figsize=(8, 4))
plt.plot(sales_ts)
plt.xlabel('Years')
plt.ylabel('Tractor Sales')
# Out:
# Text(0,0.5,'Tractor Sales')

# %% [markdown]
# # Task 7: Read Environmental CO2 Emission Series

# %%
Emission = pd.read_csv("Emission.csv")
Emission.head(5)
# Out:
#    Year Month  CO2 Emission
# 0  1973   Jan       106.363
# 1  1973   Feb       101.760
# 2  1973   Mar       110.553
# 3  1973   Apr       104.734
# 4  1973   May       114.897

# %%
dates = pd.date_range(start='1973-01-01', freq='MS', periods=len(Emission))

# %%
import calendar
Emission['Month'] = dates.month
Emission['Month'] = Emission['Month'].apply(lambda x: calendar.month_abbr[x])
Emission['Year'] = dates.year

# %%
Emission.rename(columns={'CO2_Emission':'CO2 Emission'}, inplace=True)
Emission = Emission[['Month', 'Year', 'CO2 Emission']]

# %%
Emission.set_index(dates, inplace=True)
Emission.head(5)
# Out:
#            Month  Year  CO2 Emission
# 1973-01-01   Jan  1973       106.363
# 1973-02-01   Feb  1973       101.760
# 1973-03-01   Mar  1973       110.553
# 1973-04-01   Apr  1973       104.734
# 1973-05-01   May  1973       114.897

# %%
# extract out the time-series
sales_ts = Emission['CO2 Emission']

# %%
plt.figure(figsize=(8, 4))
plt.plot(sales_ts)
plt.xlabel('Years')
plt.ylabel('CO2 Emission')
# Out:
# Text(0,0.5,'CO2 Emission')

# %% [markdown]
# # Task 8: Reading Retal Food Sales Series

# %%
RetailFood = pd.read_csv("RetailFood.csv")
RetailFood.head(5)
# Out:
#    Year Month    Food
# 0  1992   Jan  164083
# 1  1992   Feb  164260
# 2  1992   Mar  163747
# 3  1992   Apr  164759
# 4  1992   May  165617

# %%
dates = pd.date_range(start='1992-01-01', freq='MS', periods=len(RetailFood))

# %%
import calendar
RetailFood['Month'] = dates.month
RetailFood['Month'] = RetailFood['Month'].apply(lambda x: calendar.month_abbr[x])
RetailFood['Year'] = dates.year

# %%
RetailFood.rename(columns={'Food':'Foods'}, inplace=True)
RetailFood = RetailFood[['Month', 'Year', 'Foods']]

# %%
RetailFood.set_index(dates, inplace=True)
RetailFood.head(5)
# Out:
#            Month  Year   Foods
# 1992-01-01   Jan  1992  164083
# 1992-02-01   Feb  1992  164260
# 1992-03-01   Mar  1992  163747
# 1992-04-01   Apr  1992  164759
# 1992-05-01   May  1992  165617

# %%
# extract out the time-series
sales_ts = RetailFood['Foods']

# %%
plt.figure(figsize=(8, 4))
plt.plot(sales_ts)
plt.xlabel('Years')
plt.ylabel('Foods')
# Out:
# Text(0,0.5,'Foods')

# %% [markdown]
# # Task 9: Reading Mauna Loa Emission Series

# %%
MaunaLoa = pd.read_csv("MaunaLoa.csv")
MaunaLoa.head(5)
# Out:
#    Year Month  CO2 ppm
# 0  1965   Jan   319.32
# 1  1965   Feb   320.36
# 2  1965   Mar   320.82
# 3  1965   Apr   322.06
# 4  1965   May   322.17

# %%
dates = pd.date_range(start='1965-01-01', freq='MS', periods=len(MaunaLoa))

# %%
import calendar
MaunaLoa['Month'] = dates.month
MaunaLoa['Month'] = MaunaLoa['Month'].apply(lambda x: calendar.month_abbr[x])
MaunaLoa['Year'] = dates.year

# %%
#Tractor.drop(['Month-Year'], axis=1, inplace=True)
MaunaLoa.rename(columns={'CO2_ppm':'CO2 ppm'}, inplace=True)
MaunaLoa = MaunaLoa[['Month', 'Year', 'CO2 ppm']]

# %%
MaunaLoa.set_index(dates, inplace=True)
MaunaLoa.head(5)
# Out:
#            Month  Year  CO2 ppm
# 1965-01-01   Jan  1965   319.32
# 1965-02-01   Feb  1965   320.36
# 1965-03-01   Mar  1965   320.82
# 1965-04-01   Apr  1965   322.06
# 1965-05-01   May  1965   322.17

# %%
# extract out the time-series
sales_ts = MaunaLoa['CO2 ppm']

# %%
plt.figure(figsize=(8, 4))
plt.plot(sales_ts)
plt.xlabel('Years')
plt.ylabel('CO2 ppm')
# Out:
# Text(0,0.5,'CO2 ppm')

# %% [markdown]
# # Visualization of Seasonality: Quarterly Turnover

# %%
quarterly_turnover = pd.pivot_table(Turnover, values = "Turnover", columns = "Quarter", index = "Year")
quarterly_turnover
# Out:
# Quarter       Q1       Q2       Q3       Q4
# Year
# 1982         NaN      NaN  13423.2  13128.8
# 1983     15398.8  12964.2  13133.5  13271.7
# 1984     15596.3  13018.0  13409.3  13304.2
# 1985     15873.9  13366.5  13998.6  14045.1
# 1986     16650.3  13598.4  14183.2  14128.5
# 1987     16380.7  13512.8  14022.1  14231.8
# 1988     16737.0  14004.5  14165.5  14203.9
# 1989     16895.1  14248.2  14719.5  14855.8
# 1990     17361.6  14585.2  14873.5  14798.4
# 1991     17115.2  14284.9  14558.8  14914.3
# 1992     17342.3      NaN      NaN      NaN

# %%
plt.figure(figsize=(24,8))
quarterly_turnover.plot()

# %%
quarterly_turnover.boxplot()

# %% [markdown]
# # Task 1: Seasonality of Portugal Port

# %%
Portugal_pmax = pd.pivot_table(Portugal, values = "Pax", columns = "Quarter", index = "Year")
Portugal_pmax.head()
# Out:
# Quarter  Q1  Q2   Q3  Q4
# Year
# 2000     21  61  119  30
# 2001     16  71  124  33
# 2002     25  63  122  27
# 2003     23  77  149  39
# 2004     31  82  150  45

# %%
plt.figure(figsize=(24,8))
Portugal_pmax.plot()
plt.legend(loc='upper left')

# %%
Portugal_pmax.boxplot()

# %% [markdown]
# # Task 2: Seasonality of Petrol Consumption

# %%
Petrol_Consumption = pd.pivot_table(Petrol, values = "Consumption", columns = "Quarter", index = "Year")
Petrol_Consumption.head()
# Out:
# Quarter        Q1        Q2        Q3        Q4
# Year
# 2001     14.97800  11.09900  10.05700  10.45400
# 2002      9.29500   7.95200   8.06300  10.93300
# 2003     12.27800  10.84700  10.71800  10.85900
# 2004      9.09425   5.67257   5.32862   5.51024
# 2005      7.08428   5.23772   6.36947   6.71848

# %%
plt.figure(figsize=(24,8))
Petrol_Consumption.plot()

# %%
Petrol_Consumption.boxplot()

# %% [markdown]
# # Visualization of Seasonality: Monthly Temperature

# %%
monthly_temp = pd.pivot_table(AirTemp, values = "AvgTemp", columns = "Month", index = "Year")
monthly_temp = monthly_temp[['Jan','Feb','Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']]
monthly_temp
# Out:
# Month   Jan   Feb   Mar   Apr   May   Jun   Jul   Aug   Sep   Oct   Nov   Dec
# Year
# 1920   40.6  40.8  44.4  46.7  54.1  58.5  57.7  56.4  54.3  50.5  42.9  39.8
# 1921   44.2  39.8  45.1  47.0  54.1  58.7  66.3  59.9  57.0  54.2  39.7  42.8
# 1922   37.5  38.7  39.5  42.1  55.7  57.8  56.8  54.3  54.3  47.1  41.8  41.7
# 1923   41.8  40.1  42.9  45.8  49.2  52.7  64.2  59.6  54.4  49.2  36.6  37.6
# 1924   39.3  37.5  38.3  45.5  53.2  57.7  60.8  58.2  56.4  49.8  44.4  43.6
# 1925   40.0  40.5  40.8  45.1  53.8  59.4  63.5  61.0  53.0  50.0  38.1  36.3
# 1926   39.2  43.4  43.4  48.9  50.6  56.8  62.5  62.0  57.5  46.7  41.6  39.8
# 1927   39.4  38.5  45.3  47.1  51.7  55.0  60.4  60.5  54.7  50.3  42.3  35.2
# 1928   40.8  41.1  42.8  47.3  50.9  56.4  62.2  60.5  55.4  50.2  43.0  37.3
# 1929   34.8  31.3  41.0  43.9  53.1  56.9  62.5  60.3  59.8  49.2  42.9  41.9
# 1930   41.6  37.1  41.2  46.9  51.2  60.4  60.1  61.6  57.0  50.9  43.0  38.8
# ...

# %%
monthly_temp.plot()

# %%
plt.figure(figsize=(16,8))
monthly_temp.boxplot()

# %% [markdown]
# # Task 3: Seasonality of Champagne Sales

# %%
Champagne_Sales = pd.pivot_table(Champagne, values = "Sales", columns = "Month", index = "Year")
Champagne_Sales = Champagne_Sales[['Jan','Feb','Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']]
Champagne_Sales.head()
# Out:
# Month     Jan     Feb     Mar     Apr     May     Jun     Jul     Aug     Sep  \
# Year
# 1964   2815.0  2672.0  2755.0  2721.0  2946.0  3036.0  2282.0  2212.0  2922.0
# 1965   2541.0  2475.0  3031.0  3266.0  3776.0  3230.0  3028.0  1759.0  3595.0
# 1966   3113.0  3006.0  4047.0  3523.0  3937.0  3986.0  3260.0  1573.0  3528.0
# 1967   5375.0  3088.0  3718.0  4514.0  4520.0  4539.0  3663.0  1643.0  4739.0
# 1968   3633.0  4292.0  4154.0  4121.0  4647.0  4753.0  3965.0  1723.0  5048.0
#
# Month     Oct     Nov      Dec
# Year
# 1964   4301.0  5764.0   7312.0
# 1965   4474.0  6838.0   8357.0
# 1966   5211.0  7614.0   9254.0
# 1967   5428.0  8314.0  10651.0
# 1968   6922.0  9858.0  11331.0

# %%
Champagne_Sales.plot()
plt.legend(loc='upper left')

# %%
plt.figure(figsize=(16,8))
Champagne_Sales.boxplot()

# %% [markdown]
# # Task 4: Seasonality of Air Passengers

# %%
AirPax_Pax = pd.pivot_table(AirPax, values = "Pax", columns = "Month", index = "Year")
AirPax_Pax = AirPax_Pax[['Jan','Feb','Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']]
AirPax_Pax.head()
# Out:
# Month  Jan  Feb  Mar  Apr  May  Jun  Jul  Aug  Sep  Oct  Nov  Dec
# Year
# 1949   112  118  132  129  121  135  148  148  136  119  104  118
# 1950   115  126  141  135  125  149  170  170  158  133  114  140
# 1951   145  150  178  163  172  178  199  199  184  162  146  166
# 1952   171  180  193  181  183  218  230  242  209  191  172  194
# 1953   196  196  236  235  229  243  264  272  237  211  180  201

# %%
AirPax_Pax.plot()

# %%
plt.figure(figsize=(16,8))
AirPax_Pax.boxplot()

# %% [markdown]
# # Task 5: Seasonality of Tractor Sales

# %%
Tractor_Sold = pd.pivot_table(Tractor, values = "Tractor-Sales", columns = "Month", index = "Year")
Tractor_Sold = Tractor_Sold[['Jan','Feb','Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']]
Tractor_Sold.head()
# Out:
# Month  Jan  Feb  Mar  Apr  May  Jun  Jul  Aug  Sep  Oct  Nov  Dec
# Year
# 2003   141  157  185  199  203  189  207  207  171  150  138  165
# 2004   145  168  197  208  210  209  238  238  199  168  152  196
# 2005   183  200  249  251  289  249  279  279  232  204  194  232
# 2006   215  239  270  279  307  305  322  339  263  241  229  272
# 2007   247  261  330  362  385  340  370  381  299  266  239  281

# %%
Tractor_Sold.plot()

# %%
plt.figure(figsize=(16,8))
Tractor_Sold.boxplot()

# %% [markdown]
# # Task 6: Seasonality of CO2 Emission

# %%
Emission_CO2 = pd.pivot_table(Emission, values = "CO2 Emission", columns = "Month", index = "Year")
Emission_CO2 = Champagne_Sales[['Jan','Feb','Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']]
Emission_CO2.head()
# Out:
# Month     Jan     Feb     Mar     Apr     May     Jun     Jul     Aug     Sep  \
# Year
# 1964   2815.0  2672.0  2755.0  2721.0  2946.0  3036.0  2282.0  2212.0  2922.0
# 1965   2541.0  2475.0  3031.0  3266.0  3776.0  3230.0  3028.0  1759.0  3595.0
# 1966   3113.0  3006.0  4047.0  3523.0  3937.0  3986.0  3260.0  1573.0  3528.0
# 1967   5375.0  3088.0  3718.0  4514.0  4520.0  4539.0  3663.0  1643.0  4739.0
# 1968   3633.0  4292.0  4154.0  4121.0  4647.0  4753.0  3965.0  1723.0  5048.0
#
# Month     Oct     Nov      Dec
# Year
# 1964   4301.0  5764.0   7312.0
# 1965   4474.0  6838.0   8357.0
# 1966   5211.0  7614.0   9254.0
# 1967   5428.0  8314.0  10651.0
# 1968   6922.0  9858.0  11331.0

# %%
Emission_CO2.plot()
plt.legend(loc='upper left')

# %%
plt.figure(figsize=(16,8))
Emission_CO2.boxplot()

# %% [markdown]
# # Task 7: Seasonality of Retail Food Sales

# %%
RetailFood_Foods = pd.pivot_table(RetailFood, values = "Foods", columns = "Month", index = "Year")
RetailFood_Foods = RetailFood_Foods[['Jan','Feb','Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']]
RetailFood_Foods.head()
# Out:
# Month       Jan       Feb       Mar       Apr       May       Jun       Jul  \
# Year
# 1992   164083.0  164260.0  163747.0  164759.0  165617.0  166098.0  167305.0
# 1993   175078.0  173770.0  172328.0  176766.0  178445.0  178201.0  180759.0
# 1994   185128.0  188077.0  191588.0  191632.0  190940.0  193196.0  193763.0
# 1995   201583.0  198383.0  200230.0  201048.0  202993.0  205507.0  204959.0
# 1996   208731.0  212011.0  213855.0  214644.0  216304.0  216059.0  216374.0
#
# Month       Aug       Sep       Oct       Nov       Dec
# Year
# 1992   167797.0  169407.0  170681.0  171025.0  172995.0
# 1993   180692.0  181800.0  182910.0  184746.0  186339.0
# 1994   196157.0  197754.0  199579.0  199723.0  200670.0
# 1995   206529.0  206978.0  206157.0  208661.0  210434.0
# 1996   216355.0  219240.0  221039.0  220989.0  221898.0

# %%
RetailFood_Foods.plot()

# %%
plt.figure(figsize=(16,8))
RetailFood_Foods.boxplot()

# %% [markdown]
# # Task 8: Seasonality of MaunaLoa

# %%
MaunaLoa_CO2ppm = pd.pivot_table(MaunaLoa, values = "CO2 ppm", columns = "Month", index = "Year")
MaunaLoa_CO2ppm = MaunaLoa_CO2ppm[['Jan','Feb','Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']]
MaunaLoa_CO2ppm.head()
# Out:
# Month     Jan     Feb     Mar     Apr     May     Jun     Jul     Aug     Sep  \
# Year
# 1965   319.32  320.36  320.82  322.06  322.17  321.95  321.20  318.81  317.82
# 1966   319.94  320.98  321.81  323.03  323.36  323.11  321.65  319.64  317.86
# 1967   321.65  321.81  322.36  323.67  324.17  323.39  321.93  320.29  318.58
# 1968   321.88  322.47  323.17  324.23  324.88  324.75  323.47  321.34  319.56
# 1969   323.40  324.21  325.33  326.31  327.01  326.24  325.37  323.12  321.85
#
# Month     Oct     Nov     Dec
# Year
# 1965   317.37  318.93  319.09
# 1966   317.25  319.06  320.26
# 1967   318.60  319.98  321.25
# 1968   319.45  320.45  321.92
# 1969   321.31  322.31  323.72

# %%
MaunaLoa_CO2ppm.plot()
plt.legend(loc='best')

# %%
plt.figure(figsize=(16,8))
MaunaLoa_CO2ppm.boxplot()

# %% [markdown]
# # Simple Forecasts: Average and Moving Average

# %% [markdown]
# # MA(5) for US GDP

# %%
mvg_avg_USGDP = USGDP.copy()
mvg_avg_USGDP['moving_avg_forecast'] = USGDP['GDP'].rolling(5).mean()
plt.plot(USGDP['GDP'], label='US GDP')
plt.plot(mvg_avg_USGDP['moving_avg_forecast'], label='US GDP MA(5)')
plt.legend(loc='best')

# %% [markdown]
# # Task 1: MA(3) for India GDP

# %%
mvg_avg_GDPIND = GDPIND.copy()
mvg_avg_GDPIND['moving_avg_forecast'] = GDPIND['GDPpercapita'].rolling(3).mean()
plt.plot(GDPIND['GDPpercapita'], label='India GDP')
plt.plot(mvg_avg_GDPIND['moving_avg_forecast'], label='India MA(3)')
plt.legend(loc='best')

# %% [markdown]
# # Task 2: MA(7) for Daily Wage

# %%
mvg_avg_ENGWAGE = ENGWAGE.copy()
mvg_avg_ENGWAGE['moving_avg_forecast'] = ENGWAGE['DailyWage'].rolling(7).mean()
plt.plot(ENGWAGE['DailyWage'], label='Daily Wage GDP')
plt.plot(mvg_avg_ENGWAGE['moving_avg_forecast'], label='Daily Wage MA(7)')
plt.legend(loc='best')

# %% [markdown]
# # MA Forecast for Crude Oil

# %%
CrdOil = pd.read_csv('CrudeOil.csv')
CrdOil.head()
date_rng = pd.date_range(start='4/4/1983', end='27/11/2012', freq='B')
#date_rng
CrdOil['TimeIndex'] = pd.DataFrame(date_rng, columns=['Weekday'])
CrdOil.head()
# Out:
#          Date  Weekday  Price  TimeIndex
# 0  1983-04-04        2  29.44 1983-04-04
# 1  1983-04-05        3  29.71 1983-04-05
# 2  1983-04-06        4  29.92 1983-04-06
# 3  1983-04-07        5  30.17 1983-04-07
# 4  1983-04-08        6  30.38 1983-04-08

# %%
plt.plot(CrdOil.TimeIndex, CrdOil.Price)
plt.legend(loc='best')
pyplot.show()

# %%
mvg_avg_oil1 = CrdOil.copy()
mvg_avg_oil2 = CrdOil.copy()
mvg_avg_oil3 = CrdOil.copy()

mvg_avg_oil1['moving_avg_forecast'] = CrdOil['Price'].rolling(300).mean()
mvg_avg_oil2['moving_avg_forecast'] = CrdOil['Price'].rolling(900).mean()
mvg_avg_oil3['moving_avg_forecast'] = CrdOil['Price'].rolling(1500).mean()

mvg_avg_oil3.head()
# Out:
#          Date  Weekday  Price  TimeIndex  moving_avg_forecast
# 0  1983-04-04        2  29.44 1983-04-04                  NaN
# 1  1983-04-05        3  29.71 1983-04-05                  NaN
# 2  1983-04-06        4  29.92 1983-04-06                  NaN
# 3  1983-04-07        5  30.17 1983-04-07                  NaN
# 4  1983-04-08        6  30.38 1983-04-08                  NaN

# %%
CrdOil.head()
# Out:
#          Date  Weekday  Price  TimeIndex
# 0  1983-04-04        2  29.44 1983-04-04
# 1  1983-04-05        3  29.71 1983-04-05
# 2  1983-04-06        4  29.92 1983-04-06
# 3  1983-04-07        5  30.17 1983-04-07
# 4  1983-04-08        6  30.38 1983-04-08

# %%
plt.figure(figsize=(16,8))
plt.plot(CrdOil['Price'], label='Crude Oil Price')
plt.plot(mvg_avg_oil1['moving_avg_forecast'], label='MA(300)')
plt.plot(mvg_avg_oil2['moving_avg_forecast'], label='MA(900)')
plt.plot(mvg_avg_oil3['moving_avg_forecast'], label='MA(1500)')
plt.legend(loc='upper left')

# %% [markdown]
# # AirTemp

# %%
temp_avg = AirTemp.copy()
temp_avg['avg_forecast'] = AirTemp['AvgTemp'].mean()

# %%
plt.figure(figsize=(12,8))
plt.plot(AirTemp['AvgTemp'], label='Data')
plt.plot(temp_avg['avg_forecast'], label='Average Forecast')
plt.legend(loc='best')

# %%
mvg_avg = AirTemp.copy()
mvg_avg['moving_avg_forecast'] = AirTemp['AvgTemp'].rolling(12).mean()
plt.plot(AirTemp['AvgTemp'], label='Average Temperature')
plt.plot(mvg_avg['moving_avg_forecast'], label='Moving Average Forecast 12')
plt.legend(loc='best')

# %%
mvg_avg1 = AirTemp.copy()
mvg_avg2 = AirTemp.copy()
mvg_avg3 = AirTemp.copy()

mvg_avg1['moving_avg_forecast'] = AirTemp['AvgTemp'].rolling(12).mean()
#mvg_avg.head(15)
mvg_avg2['moving_avg_forecast'] = AirTemp['AvgTemp'].rolling(15).mean()
#mvg_avg.tail(6)
mvg_avg3['moving_avg_forecast'] = AirTemp['AvgTemp'].rolling(6).mean()

# %%
#plt.figure(figsize=(16,8))
plt.plot(AirTemp['AvgTemp'], label='Average Temperature')
plt.plot(mvg_avg1['moving_avg_forecast'], label='Moving Average Forecast 12')
plt.plot(mvg_avg2['moving_avg_forecast'], label='Moving Average Forecast 15')
plt.plot(mvg_avg3['moving_avg_forecast'], label='Moving Average Forecast 06')
plt.legend(loc='best')

# %% [markdown]
# # Seasonal Decomposition

# %%
import statsmodels.api as sm

# %%
decompTurnover = sm.tsa.seasonal_decompose(Turnover.Turnover, model="additive", freq=4)
decompTurnover.plot()
plt.show()

# %%
trend = decompTurnover.trend
seasonal = decompTurnover.seasonal
residual = decompTurnover.resid

# %%
trend.head(12)
# Out:
# 0            NaN
# 1            NaN
# 2     13692.5375
# 3     13674.1875
# 4     13716.7375
# 5     13748.1500
# 6     13789.3500
# 7     13827.8875
# 8     13866.6500
# 9     13944.9125
# 10    14062.1375
# 11    14228.4125
# Name: Turnover, dtype: float64

# %%
seasonal.head(12)
# Out:
# 0     -524.613498
# 1     -510.713672
# 2     1894.960113
# 3     -859.632943
# 4     -524.613498
# 5     -510.713672
# 6     1894.960113
# 7     -859.632943
# 8     -524.613498
# 9     -510.713672
# 10    1894.960113
# 11    -859.632943
# Name: Turnover, dtype: float64

# %%
residual.head(12)
# Out:
# 0            NaN
# 1            NaN
# 2    -188.697613
# 3     149.645443
# 4     -58.624002
# 5      34.263672
# 6     -88.010113
# 7      49.745443
# 8      67.263498
# 9    -129.998828
# 10    -83.197613
# 11     -2.279557
# Name: Turnover, dtype: float64

# %%
print(sum(seasonal[:12]))
# Out:
# 5.684341886080801e-13

# %%
plt.plot(seasonal[:12])
plt.show()

# %%
Champ = pd.read_csv('Champagne.csv')
Champ.head()
date_rng = pd.date_range(start='1/1/1964', end='30/9/1972', freq='M')
date_rng
Champ['TimeIndex'] = pd.DataFrame(date_rng, columns=['Month'])
Champ.head()
plt.plot(Champ.TimeIndex, Champ.Sales)
plt.legend(loc='upper left')
pyplot.show()

# %%
decompChamp = sm.tsa.seasonal_decompose(Champ.Sales, model="additive", freq=12)
decompChamp.plot()
plt.show()

# %%
trendC = decompChamp.trend
seasonalC = decompChamp.seasonal
residualC = decompChamp.resid

# %%
trendC.head(12)
# Out:
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# 5             NaN
# 6     3466.750000
# 7     3447.125000
# 8     3450.416667
# 9     3484.625000
# 10    3541.916667
# 11    3584.583333
# Name: Sales, dtype: float64

# %%
seasonalC.head(12)
# Out:
# 0    -1223.411582
# 1    -1624.250124
# 2     -979.229291
# 3     -850.244916
# 4     -652.096106
# 5     -671.173487
# 6    -1242.500124
# 7    -3060.505332
# 8     -312.390749
# 9      965.729043
# 10    3730.130084
# 11    5919.942584
# Name: Sales, dtype: float64

# %%
residualC.head(12)
# Out:
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# 5             NaN
# 6       57.750124
# 7     1825.380332
# 8     -216.025918
# 9     -149.354043
# 10   -1508.046751
# 11   -2192.525918
# Name: Sales, dtype: float64

# %%
print(sum(seasonalC[:12]))
# Out:
# -1.8189894035458565e-12

# %%
plt.plot(seasonalC[:12])
plt.show()

# %%
plt.plot(seasonalC[:24])
plt.show()

# %%
AirPax = pd.read_csv('AirPax.csv')
AirPax.head()
date_rng = pd.date_range(start='1/1/1949', end='31/12/1960', freq='M')
date_rng
AirPax['TimeIndex'] = pd.DataFrame(date_rng, columns=['Month'])
AirPax.head()
plt.plot(AirPax.TimeIndex, AirPax.Pax)
plt.legend(loc='best')
pyplot.show()

# %%
decompAirPax = sm.tsa.seasonal_decompose(AirPax.Pax, model="multiplicative", freq=12)
decompAirPax.plot()
plt.show()

# %%
seasonal = decompAirPax.seasonal
seasonal.head()
# Out:
# 0    0.910230
# 1    0.883625
# 2    1.007366
# 3    0.975906
# 4    0.981378
# Name: Pax, dtype: float64

# %%
print(sum(seasonal[:12]))
# Out:
# 12.0

# %%
plt.plot(seasonal[:12])
plt.show()

# %% [markdown]
# # Split Data in Training and Test

# %%
Petrol = pd.read_csv('Petrol.csv')
Petrol.head()
# Out:
#    Year Quarter  Consumption
# 0  2001      Q1       14.978
# 1  2001      Q2       11.099
# 2  2001      Q3       10.057
# 3  2001      Q4       10.454
# 4  2002      Q1        9.295

# %%
date_rng = pd.date_range(start='1/1/2001', end='30/9/2013', freq='Q')
date_rng
Petrol['TimeIndex'] = pd.DataFrame(date_rng, columns=['Quarter'])
Petrol.head()
plt.plot(Petrol.TimeIndex, Petrol.Consumption)
pyplot.show()

# %%
#Creating train and test set 
train=Petrol[0:int(len(Petrol)*0.7)] 
test=Petrol[int(len(Petrol)*0.7):]

# %%
type(train)
train.head()
# Out:
#    Year Quarter  Consumption  TimeIndex
# 0  2001      Q1       14.978 2001-03-31
# 1  2001      Q2       11.099 2001-06-30
# 2  2001      Q3       10.057 2001-09-30
# 3  2001      Q4       10.454 2001-12-31
# 4  2002      Q1        9.295 2002-03-31

# %%
plt.plot(train.Consumption)
plt.plot(test.Consumption)
pyplot.show()

# %%
train.Consumption.plot()
test.Consumption.plot()

# %% [markdown]
# # Simple Exponential Smoothing

# %%
from statsmodels.tsa.holtwinters import ExponentialSmoothing, SimpleExpSmoothing, Holt

# %%
# create class
model = SimpleExpSmoothing(np.asarray(train['Consumption']))

# %%
# fit model
model99_fit = model.fit(smoothing_level=0.99,optimized=False)
model5_fit = model.fit(smoothing_level=0.5,optimized=False)
model1_fit = model.fit(smoothing_level=0.1,optimized=False)

# %%
fcst_SES = test.copy()

# %%
fcst_SES['SES99'] = model99_fit.forecast(len(test['Consumption']))
fcst_SES['SES5'] = model5_fit.forecast(len(test['Consumption']))
fcst_SES['SES1'] = model1_fit.forecast(len(test['Consumption']))

# %%
plt.figure(figsize=(16,8))
plt.plot(train['Consumption'], label='Train')
plt.plot(test['Consumption'], label='Test')
plt.plot(fcst_SES['SES99'], label='SES99')
plt.plot(fcst_SES['SES5'], label='SES5')
plt.plot(fcst_SES['SES1'], label='SES1')
plt.legend(loc='best')

# %%
fcst_SES['SES99']
# Out:
# 35    1.986998
# 36    1.986998
# 37    1.986998
# 38    1.986998
# 39    1.986998
# 40    1.986998
# 41    1.986998
# 42    1.986998
# 43    1.986998
# 44    1.986998
# 45    1.986998
# 46    1.986998
# 47    1.986998
# 48    1.986998
# 49    1.986998
# 50    1.986998
# Name: SES99, dtype: float64

# %%
#
def mean_absolute_percentage_error(y_true, y_pred): 
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# %%
mean_absolute_percentage_error(test['Consumption'],fcst_SES['SES99'])
# Out:
# 94.50460480680182

# %%
rmse = sqrt(mean_squared_error(test['Consumption'],fcst_SES['SES99']))
rmse
# Out:
# 0.9437879263674692

# %%
model_opt_fit = model.fit()

# %%
model_opt_fit.model.params
# Out:
# {'smoothing_level': 1.0,
#  'smoothing_slope': nan,
#  'smoothing_seasonal': nan,
#  'damping_slope': nan,
#  'initial_level': 14.978,
#  'initial_slope': nan,
#  'initial_seasons': array([], dtype=float64),
#  'use_boxcox': False,
#  'lamda': None,
#  'remove_bias': False}

# %%
model_opt_fit.fittedvalues
# Out:
# array([14.978  , 14.978  , 11.099  , 10.057  , 10.454  ,  9.295  ,
#         7.952  ,  8.063  , 10.933  , 12.278  , 10.847  , 10.718  ,
#        10.859  ,  9.09425,  5.67257,  5.32862,  5.51024,  7.08428,
#         5.23772,  6.36947,  6.71848,  4.95971,  3.76986,  3.9876 ,
#         4.2695 ,  5.04027,  4.07531,  2.90378,  2.92244,  2.9911 ,
#         1.91147,  2.03605,  2.27635,  3.74029,  2.51021])

# %%
plt.figure(figsize=(16,8))
plt.plot(train['Consumption'], label='Train')
plt.plot(model_opt_fit.fittedvalues, label='Fits')
plt.plot(model99_fit.fittedvalues, label='Fits99')
plt.plot(model5_fit.fittedvalues, label='Fits5')
plt.plot(model1_fit.fittedvalues, label='Fits1')
plt.legend(loc='best')

# %% [markdown]
# # Double Exponential (Holt)

# %%
model = Holt(np.asarray(train['Consumption']))
model81_fit = model.fit(smoothing_level = 0.8,smoothing_slope = 0.1,optimized=False)

# %%
model93_fit = model.fit(smoothing_level = 0.9,smoothing_slope = 0.3,optimized=False)

# %%
fcst_Holt = test.copy()

# %%
fcst_Holt['Holt81'] = model81_fit.forecast(len(test['Consumption']))
fcst_Holt['Holt93'] = model93_fit.forecast(len(test['Consumption']))

# %%
plt.figure(figsize=(16,8))
plt.plot(train['Consumption'], label='Train')
plt.plot(model81_fit.fittedvalues, label='Fitted Values 81')
plt.plot(model93_fit.fittedvalues, label='Fitted Values 93')
plt.plot(test['Consumption'], label='Test')
plt.plot(fcst_Holt['Holt81'], label='Holt81')
plt.plot(fcst_Holt['Holt93'], label='Holt93')
plt.legend(loc='best')

# %%
modelopt_fit = model.fit()

# %%
fcst_Holt['Opt'] = modelopt_fit.forecast(len(test['Consumption']))

# %%
plt.figure(figsize=(16,8))
plt.plot(train['Consumption'], label='Train')
plt.plot(modelopt_fit.fittedvalues, label='Fitted Values')
plt.plot(test['Consumption'], label='Test')
plt.plot(fcst_Holt['Opt'], label='HoltOpt')
plt.legend(loc='best')

# %%
modelopt_fit.model.params
# Out:
# {'smoothing_level': 1.0,
#  'smoothing_slope': 0.019968997164700898,
#  'smoothing_seasonal': nan,
#  'damping_slope': nan,
#  'initial_level': 15.127122092560768,
#  'initial_slope': 0.0,
#  'initial_seasons': array([], dtype=float64),
#  'use_boxcox': False,
#  'lamda': None,
#  'remove_bias': False}

# %%
#Creating train and test set 
#trainPax=AirPax[0:int(len(AirPax)*0.8)] 
#testPax=AirPax[int(len(AirPax)*0.8):]

# %% [markdown]
# # Fitting Holt-Winters Model

# %%
trainPax=AirPax[0:120] 
testPax=AirPax[120:]
trainPax.head()
# Out:
#    Year Month  Pax  TimeIndex
# 0  1949   Jan  112 1949-01-31
# 1  1949   Feb  118 1949-02-28
# 2  1949   Mar  132 1949-03-31
# 3  1949   Apr  129 1949-04-30
# 4  1949   May  121 1949-05-31

# %%
model1_fit=ExponentialSmoothing(np.asarray(trainPax['Pax']), seasonal_periods=12 ,seasonal='add').fit(optimized=True)

# %%
fcst_HoltW = testPax.copy()
fcst_HoltW['HoltW'] = model1_fit.forecast(len(testPax['Pax']))
plt.figure(figsize=(16,8))
plt.plot(trainPax['Pax'], label='Train')
plt.plot(testPax['Pax'], label='Test')
plt.plot(fcst_HoltW['HoltW'], label='HoltWinters')
plt.legend(loc='best')

# %%
model2_fit = ExponentialSmoothing(np.asarray(trainPax['Pax']),  seasonal_periods=12, trend='add',seasonal='mul').fit(smoothing_slope = 0.2, smoothing_seasonal=0.8, smoothing_level = 0.2, optimized=False)

# %%
model2opt_fit = ExponentialSmoothing(np.asarray(trainPax['Pax']),  seasonal_periods=12, trend='add',seasonal='mul').fit(optimized=True)

# %%
fcst_HoltW['HoltWM'] = model2opt_fit.forecast(len(testPax['Pax']))
plt.figure(figsize=(16,8))
plt.plot(trainPax['Pax'], label='Train')
plt.plot(testPax['Pax'], label='Test')
plt.plot(fcst_HoltW['HoltW'], label='HoltWinters Additive')
plt.plot(fcst_HoltW['HoltWM'], label='HoltWinters Multiplicative')
plt.legend(loc='best')

# %%
model1_fit.model.params
# Out:
# {'smoothing_level': 0.3157894714033458,
#  'smoothing_slope': 0.0,
#  'smoothing_seasonal': 0.6842105240349247,
#  'damping_slope': nan,
#  'initial_level': 205.6631953187601,
#  'initial_slope': nan,
#  'initial_seasons': array([ -97.29166792,  -91.13247934,  -78.09209237,  -83.04427655,
#          -91.56395023,  -77.42007363,  -64.83863223,  -66.66925421,
#          -80.15722395,  -98.23335742, -112.13808397,  -94.96094134]),
#  'use_boxcox': False,
#  'lamda': None,
#  'remove_bias': False}

# %%
model2opt_fit.model.params
# Out:
# {'smoothing_level': 0.3157894736842105,
#  'smoothing_slope': 0.052631290217294194,
#  'smoothing_seasonal': 0.6842105263157894,
#  'damping_slope': nan,
#  'initial_level': 212.3998371369524,
#  'initial_slope': 1.0836355016145112,
#  'initial_seasons': array([0.55116032, 0.57513599, 0.6299275 , 0.60258105, 0.55808768,
#         0.62115206, 0.68396707, 0.68151938, 0.62365319, 0.54212734,
#         0.47820682, 0.55862355]),
#  'use_boxcox': False,
#  'lamda': None,
#  'remove_bias': False}

# %%
model2_fit.model.params
# Out:
# {'smoothing_level': 0.2,
#  'smoothing_slope': 0.2,
#  'smoothing_seasonal': 0.8,
#  'damping_slope': nan,
#  'initial_level': 212.4,
#  'initial_slope': 1.0833333333333333,
#  'initial_seasons': array([0.52730697, 0.55555556, 0.62146893, 0.60734463, 0.56967985,
#         0.63559322, 0.69679849, 0.69679849, 0.64030132, 0.56026365,
#         0.48964218, 0.55555556]),
#  'use_boxcox': False,
#  'lamda': None,
#  'remove_bias': False}

# %%
mean_absolute_percentage_error(testPax['Pax'],fcst_HoltW['HoltWM'])
# Out:
# 7.5417145675032975

# %% [markdown]
# # Inclass hands on***

# %% [markdown]
# #Expereience

# %% [markdown]
# # Seasonal Decomposition MaunaLoa data

# %%
MaunaLoa = pd.read_csv('MaunaLoa.csv')
MaunaLoa.head()
date_rng = pd.date_range(start='1/1/1965', end='31/12/1980', freq='M')
date_rng
MaunaLoa['TimeIndex'] = pd.DataFrame(date_rng, columns=['Month'])
MaunaLoa.head()
plt.plot(MaunaLoa.TimeIndex, MaunaLoa['CO2 ppm'])
plt.legend(loc='best')
pyplot.show()

# %%
decompMaunaLoaa = sm.tsa.seasonal_decompose(MaunaLoa['CO2 ppm'], model="additive", freq=12)
decompMaunaLoaa.plot()
plt.show()

# %%
seasonalma = decompMaunaLoaa.seasonal
seasonalma.head(12)
# Out:
# 0    -0.066935
# 1     0.527870
# 2     1.323065
# 3     2.369148
# 4     2.812065
# 5     2.290287
# 6     0.900287
# 7    -1.133852
# 8    -2.860241
# 9    -3.156602
# 10   -2.025519
# 11   -0.979574
# Name: CO2 ppm, dtype: float64

# %%
print(sum(seasonalma[:12]))
# Out:
# 2.220446049250313e-16

# %%
plt.plot(seasonalma[:12])
plt.show()

# %%
plt.plot(seasonalma[:36])
plt.show()

# %% [markdown]
# # Seasonal Decomposition Tractor sale data

# %%
TractorSales = pd.read_csv('TractorSales.csv')
TractorSales.head()
date_rng = pd.date_range(start='2003-01-01', freq='MS', periods=len(Tractor))
date_rng
TractorSales['TimeIndex'] = pd.DataFrame(date_rng, columns=['Month'])
TractorSales.head()
plt.plot(TractorSales.TimeIndex,TractorSales['Number of Tractor Sold'])
plt.legend(loc='best')
pyplot.show()

# %%
decompTractorSales = sm.tsa.seasonal_decompose(TractorSales['Number of Tractor Sold'], model="multiplicative", freq=12)
decompTractorSales.plot()
plt.show()

# %%
seasonaltm = decompTractorSales.seasonal
seasonaltm.head(12)
# Out:
# 0     0.823333
# 1     0.843859
# 2     1.012370
# 3     1.080556
# 4     1.185793
# 5     1.120913
# 6     1.236024
# 7     1.230135
# 8     0.961964
# 9     0.836410
# 10    0.765533
# 11    0.903109
# Name: Number of Tractor Sold, dtype: float64

# %%
print(sum(seasonaltm[:12]))
# Out:
# 12.0

# %%
plt.plot(seasonaltm[:12])
plt.show()

# %% [markdown]
# # Split Data in Training and Test

# %%
Petrol = pd.read_csv('Petrol.csv')
Petrol.head()
# Out:
#    Year Quarter  Consumption
# 0  2001      Q1       14.978
# 1  2001      Q2       11.099
# 2  2001      Q3       10.057
# 3  2001      Q4       10.454
# 4  2002      Q1        9.295

# %%
date_rng = pd.date_range(start='1/1/2001', end='30/9/2013', freq='Q')
date_rng
Petrol['TimeIndex'] = pd.DataFrame(date_rng, columns=['Quarter'])
Petrol.head()
plt.plot(Petrol.TimeIndex, Petrol.Consumption)
pyplot.show()

# %%
#Creating train and test set 
train=Petrol[0:int(len(Petrol)*0.85)] 
test=Petrol[int(len(Petrol)*0.85):]

# %%
plt.plot(train.Consumption)
plt.plot(test.Consumption)
pyplot.show()

# %%
train.Consumption.plot()
test.Consumption.plot()

# %%
#Simple Exponential Smoothing
from statsmodels.tsa.holtwinters import ExponentialSmoothing, SimpleExpSmoothing, Holt

# %%
# create class
model = SimpleExpSmoothing(np.asarray(train['Consumption']))

# %%
# fit model
model99_fit = model.fit(smoothing_level=0.99,optimized=False)
model85_fit = model.fit(smoothing_level=0.85,optimized=False)
model5_fit = model.fit(smoothing_level=0.5,optimized=False)
model1_fit = model.fit(smoothing_level=0.1,optimized=False)

# %%
fcst_SES = test.copy()

# %%
fcst_SES['SES99'] = model99_fit.forecast(len(test['Consumption']))
fcst_SES['SES85'] = model85_fit.forecast(len(test['Consumption']))
fcst_SES['SES5'] = model5_fit.forecast(len(test['Consumption']))
fcst_SES['SES1'] = model1_fit.forecast(len(test['Consumption']))

# %%
plt.figure(figsize=(16,8))
plt.plot(train['Consumption'], label='Train')
plt.plot(test['Consumption'], label='Test')
plt.plot(fcst_SES['SES99'], label='SES99')
plt.plot(fcst_SES['SES85'], label='SES85')
plt.plot(fcst_SES['SES5'], label='SES5')
plt.plot(fcst_SES['SES1'], label='SES1')
plt.legend(loc='best')

# %%
model_opt_fit = model.fit(smoothing_level = 0.85)

# %%
model_opt_fit.model.params
# Out:
# {'smoothing_level': 0.85,
#  'smoothing_slope': nan,
#  'smoothing_seasonal': nan,
#  'damping_slope': nan,
#  'initial_level': 14.373362728326558,
#  'initial_slope': nan,
#  'initial_seasons': array([], dtype=float64),
#  'use_boxcox': False,
#  'lamda': None,
#  'remove_bias': False}

# %%
model_opt_fit.fittedvalues
# Out:
# array([14.37336273, 14.88730441, 11.66724566, 10.29853685, 10.43068053,
#         9.46535208,  8.17900281,  8.08040042, 10.50511006, 12.01206651,
#        11.02175998, 10.763564  , 10.8446846 ,  9.35681519,  6.22520678,
#         5.46310802,  5.5031702 ,  6.84711353,  5.47912903,  6.23591885,
#         6.64609583,  5.21266787,  3.98628118,  3.98740218,  4.22718533,
#         4.9183073 ,  4.20175959,  3.09847694,  2.94884554,  2.98476183,
#         2.07246377,  2.04151207,  2.24112431,  3.51541515,  2.66099077,
#         2.08350012,  1.63190352,  1.57957453,  1.16331718,  1.07397608,
#         1.34824891,  1.32560584,  1.01512988])

# %%
plt.figure(figsize=(16,8))
plt.plot(train['Consumption'], label='Train')
plt.plot(model_opt_fit.fittedvalues, label='Fits')
plt.plot(model99_fit.fittedvalues, label='Fits99')
plt.plot(model85_fit.fittedvalues, label='Fits85')
plt.plot(model5_fit.fittedvalues, label='Fits5')
plt.plot(model1_fit.fittedvalues, label='Fits1')
plt.legend(loc='best')

# %%
#
def mean_absolute_percentage_error(y_true, y_pred): 
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# %%
mean_absolute_percentage_error(test['Consumption'],fcst_SES['SES99'])
# Out:
# 13.639356052977583

# %%
mean_absolute_percentage_error(test['Consumption'],fcst_SES['SES85'])
# Out:
# 13.811735534487266

# %%
rmse = sqrt(mean_squared_error(test['Consumption'],fcst_SES['SES99']))
rmse
# Out:
# 0.18648821433353596

# %%
rmse = sqrt(mean_squared_error(test['Consumption'],fcst_SES['SES85']))
rmse
# Out:
# 0.18141888428304503

# %% [markdown]
# # Double Exponential (Holt) for petrol data

# %%
#Creating train and test set 
train=Petrol[0:int(len(Petrol)*0.85)] 
test=Petrol[int(len(Petrol)*0.85):]

# %%
plt.plot(train.Consumption)
plt.plot(test.Consumption)
pyplot.show()

# %%
model = Holt(np.asarray(train['Consumption']))
model99_fit = model.fit(smoothing_level = 0.99,smoothing_slope = 0.7,optimized=False)

# %%
model85_fit = model.fit(smoothing_level = 0.85,smoothing_slope = 0.5,optimized=False)

# %%
fcst_Holt = test.copy()

# %%
fcst_Holt['Holt99'] = model99_fit.forecast(len(test['Consumption']))
fcst_Holt['Holt85'] = model85_fit.forecast(len(test['Consumption']))

# %%
plt.figure(figsize=(16,8))
plt.plot(train['Consumption'], label='Train')
plt.plot(model99_fit.fittedvalues, label='Fitted Values 99')
plt.plot(model85_fit.fittedvalues, label='Fitted Values 85')
plt.plot(test['Consumption'], label='Test')
plt.plot(fcst_Holt['Holt99'], label='Holt99')
plt.plot(fcst_Holt['Holt85'], label='Holt85')
plt.legend(loc='best')

# %%
mean_absolute_percentage_error(test['Consumption'],fcst_Holt['Holt99'])
# Out:
# 77.09915553814433

# %%
mean_absolute_percentage_error(test['Consumption'],fcst_Holt['Holt85'])
# Out:
# 78.53907075720159

# %%
rmse = sqrt(mean_squared_error(test['Consumption'],fcst_Holt['Holt99']))
rmse
# Out:
# 0.7079928523083711

# %%
rmse = sqrt(mean_squared_error(test['Consumption'],fcst_Holt['Holt85']))
rmse
# Out:
# 0.7211899878432937

# %% [markdown]
# # Double Exponential (Holt) for UDGDP

# %%
USGDP = pd.read_csv('GDPUS.csv', header=0)
USGDP.head(8)
# Out:
#    Year    GDP
# 0  1929  821.8
# 1  1930  748.9
# 2  1931  691.3
# 3  1932  599.7
# 4  1933  587.1
# 5  1934  632.6
# 6  1935  681.6
# 7  1936  777.9

# %%
date_rng = pd.date_range(start='1/1/1929', end='31/12/1991', freq='Y')
date_rng
USGDP['TimeIndex'] = pd.DataFrame(date_rng, columns=['Year'])
USGDP.head(8)
plt.plot(USGDP.TimeIndex, USGDP.GDP)
plt.legend(loc='best')
#pyplot.show()

# %%
#Creating train and test set 
train=USGDP[0:int(len(USGDP)*0.7)] 
test=USGDP[int(len(USGDP)*0.7):]

# %%
plt.plot(train.GDP)
plt.plot(test.GDP)
pyplot.show()

# %%
model1 = Holt(np.asarray(train['GDP']))
model99_fit = model1.fit(smoothing_level = 0.99,smoothing_slope = 0.05,optimized=False)

# %%
model85_fit = model1.fit(smoothing_level = 0.85,smoothing_slope = 0.09,optimized=False)

# %%
fcst_Holt = test.copy()

# %%
fcst_Holt['Holt99'] = model99_fit.forecast(len(test['GDP']))
fcst_Holt['Holt85'] = model85_fit.forecast(len(test['GDP']))

# %%
plt.figure(figsize=(16,8))
plt.plot(train['GDP'], label='Train')
plt.plot(model99_fit.fittedvalues, label='Fitted Values 99')
plt.plot(model85_fit.fittedvalues, label='Fitted Values 85')
plt.plot(test['GDP'], label='Test')
plt.plot(fcst_Holt['Holt99'], label='Holt99')
plt.plot(fcst_Holt['Holt85'], label='Holt85')
plt.legend(loc='best')

# %%
mean_absolute_percentage_error(test['GDP'],fcst_Holt['Holt99'])
# Out:
# 5.683054379371114

# %%
mean_absolute_percentage_error(test['GDP'],fcst_Holt['Holt85'])
# Out:
# 2.4941660848473575

# %%
rmse = sqrt(mean_squared_error(test['GDP'],fcst_Holt['Holt99']))
rmse
# Out:
# 309.5488405367766

# %%
rmse = sqrt(mean_squared_error(test['GDP'],fcst_Holt['Holt85']))
rmse
# Out:
# 121.3711610284993

# %% [markdown]
# # Fitting Holt-Winters Model on Airpax data

# %%
AirPax = pd.read_csv('AirPax.csv')
AirPax.head()
date_rng = pd.date_range(start='1/1/1949', end='31/12/1960', freq='M')
date_rng
AirPax['TimeIndex'] = pd.DataFrame(date_rng, columns=['Month'])
AirPax.head()
plt.plot(AirPax.TimeIndex, AirPax.Pax)
plt.legend(loc='best')
pyplot.show()

# %%
trainPax=AirPax[0:120] 
testPax=AirPax[120:]
trainPax.head()
# Out:
#    Year Month  Pax  TimeIndex
# 0  1949   Jan  112 1949-01-31
# 1  1949   Feb  118 1949-02-28
# 2  1949   Mar  132 1949-03-31
# 3  1949   Apr  129 1949-04-30
# 4  1949   May  121 1949-05-31

# %%
model01_fit = ExponentialSmoothing(np.asarray(trainPax['Pax']),  seasonal_periods=12, trend='add',seasonal='mul').fit(smoothing_slope = 0.2, smoothing_seasonal=0.8, smoothing_level = 0.2, optimized=False)

# %%
model02_fit = ExponentialSmoothing(np.asarray(trainPax['Pax']),  seasonal_periods=12, trend='add',seasonal='mul').fit(smoothing_slope = 0.05, smoothing_seasonal=0.65, smoothing_level = 0.5, optimized=False)

# %%
model03_fit = ExponentialSmoothing(np.asarray(trainPax['Pax']),  seasonal_periods=12, trend='add',seasonal='mul').fit(smoothing_slope = 0.01, smoothing_seasonal=0.65, smoothing_level = 0.35, optimized=False)

# %%
model2opt_fit = ExponentialSmoothing(np.asarray(trainPax['Pax']),  seasonal_periods=12, trend='add',seasonal='mul').fit(optimized=True)

# %%
fcst_HoltW = testPax.copy()

# %%
fcst_HoltW['Holt01'] = model01_fit.forecast(len(testPax['Pax']))
fcst_HoltW['Holt02'] = model02_fit.forecast(len(testPax['Pax']))
fcst_HoltW['Holt03'] = model03_fit.forecast(len(testPax['Pax']))
fcst_HoltW['Holtopt'] = model2opt_fit.forecast(len(testPax['Pax']))

# %%
plt.figure(figsize=(16,8))
plt.plot(trainPax['Pax'], label='Train')
plt.plot(testPax['Pax'], label='Test')
plt.plot(fcst_HoltW['Holt01'], label='Holt01')
plt.plot(fcst_HoltW['Holt02'], label='Holt02')
plt.plot(fcst_HoltW['Holt03'], label='Holt03')
plt.plot(fcst_HoltW['Holtopt'], label='Holtopt')
plt.legend(loc='best')

# %%
model2opt_fit.model.params
# Out:
# {'smoothing_level': 0.3157894736842105,
#  'smoothing_slope': 0.052631290217294194,
#  'smoothing_seasonal': 0.6842105263157894,
#  'damping_slope': nan,
#  'initial_level': 212.3998371369524,
#  'initial_slope': 1.0836355016145112,
#  'initial_seasons': array([0.55116032, 0.57513599, 0.6299275 , 0.60258105, 0.55808768,
#         0.62115206, 0.68396707, 0.68151938, 0.62365319, 0.54212734,
#         0.47820682, 0.55862355]),
#  'use_boxcox': False,
#  'lamda': None,
#  'remove_bias': False}

# %%
mean_absolute_percentage_error(testPax['Pax'],fcst_HoltW['Holt01'])
# Out:
# 8.580078688053188

# %%
mean_absolute_percentage_error(testPax['Pax'],fcst_HoltW['Holt02'])
# Out:
# 5.679607038245745

# %%
mean_absolute_percentage_error(testPax['Pax'],fcst_HoltW['Holt03'])
# Out:
# 8.392659986349226

# %%
mean_absolute_percentage_error(testPax['Pax'],fcst_HoltW['Holtopt'])
# Out:
# 7.5417145675032975

# %%
model04_fit = ExponentialSmoothing(np.asarray(AirPax['Pax']),  seasonal_periods=12, trend='add',seasonal='mul').fit(smoothing_slope = 0.05, smoothing_seasonal=0.65, smoothing_level = 0.5, optimized=False)

# %%
fcst_HoltW['Holtpred'] = model04_fit.forecast(24)

# %%
plt.figure(figsize=(16,8))
plt.plot(trainPax['Pax'], label='Train')
plt.plot(testPax['Pax'], label='Test')
plt.plot(fcst_HoltW['Holt01'], label='Holt01')
plt.plot(fcst_HoltW['Holt02'], label='Holt02')
plt.plot(fcst_HoltW['Holt03'], label='Holt03')
plt.plot(fcst_HoltW['Holtopt'], label='Holtopt')
plt.plot(fcst_HoltW['Holtpred'], label='Holtpred')
plt.legend(loc='best')

# %% [markdown]
# # Fitting Holt-Winters Model on Champagne data

# %%
Champagne = pd.read_csv('Champagne.csv')
date_rng6 = pd.date_range(start='1/1/1964', end='31/12/1972', freq='M')
Champagne['TimeIndex'] = pd.DataFrame(date_rng6, columns=['Month'])
plt.plot(Champagne.TimeIndex, Champagne.Sales)
plt.legend(loc='best')
pyplot.show()

# %%
trainchamp=Champagne[0:84] 
testchamp=Champagne[84:]
trainchamp.head()
# Out:
#    Year Month  Sales  TimeIndex
# 0  1964   Jan   2815 1964-01-31
# 1  1964   Feb   2672 1964-02-29
# 2  1964   Mar   2755 1964-03-31
# 3  1964   Apr   2721 1964-04-30
# 4  1964   May   2946 1964-05-31

# %%
model_2opt_fit = ExponentialSmoothing(np.asarray(trainchamp['Sales']),  seasonal_periods=12, trend='add',seasonal='add').fit(optimized=True)

# %%
model_2opt_fit.model.params
# Out:
# {'smoothing_level': 0.08690356767281857,
#  'smoothing_slope': 0.08688462726697466,
#  'smoothing_seasonal': 0.8204139101943045,
#  'damping_slope': nan,
#  'initial_level': 3424.492058588935,
#  'initial_slope': 31.08205847121977,
#  'initial_seasons': array([ -632.52905998,  -773.14245688,  -685.5199834 ,  -720.14803688,
#          -496.75585371,  -414.6944495 , -1167.31273183, -1247.33646521,
#          -526.83541127,   846.11015334,  2312.22529862,  3851.98523734]),
#  'use_boxcox': False,
#  'lamda': None,
#  'remove_bias': False}

# %%
fcst_HoltW = testchamp.copy()

# %%
fcst_HoltW['Holtopt'] = model_2opt_fit.forecast(len(testchamp['Sales']))

# %%
mean_absolute_percentage_error(testchamp['Sales'],fcst_HoltW['Holtopt'])
# Out:
# 22.292473886825416

# %%
model01_fit = ExponentialSmoothing(np.asarray(trainchamp['Sales']),  seasonal_periods=12, trend='add',seasonal='add').fit(smoothing_slope = 0.01, smoothing_seasonal=0.65, smoothing_level = 0.35, optimized=False)
model02_fit = ExponentialSmoothing(np.asarray(trainchamp['Sales']),  seasonal_periods=12, trend='add',seasonal='add').fit(smoothing_slope = 0.01, smoothing_seasonal=0.55, smoothing_level = 0.25, optimized=False)
model04_fit = ExponentialSmoothing(np.asarray(trainchamp['Sales']),  seasonal_periods=12, trend='add',seasonal='add').fit(smoothing_slope = 0.35, smoothing_seasonal=0.33, smoothing_level = 0.06, optimized=False)

# %%
fcst_HoltW['Holt01'] = model01_fit.forecast(len(testchamp['Sales']))
fcst_HoltW['Holt02'] = model02_fit.forecast(len(testchamp['Sales']))
fcst_HoltW['Holt04'] = model04_fit.forecast(len(testchamp['Sales']))

# %%
mean_absolute_percentage_error(testchamp['Sales'],fcst_HoltW['Holt01'])
# Out:
# 16.48654502888838

# %%
mean_absolute_percentage_error(testchamp['Sales'],fcst_HoltW['Holt02'])
# Out:
# 13.805417048869902

# %%
mean_absolute_percentage_error(testchamp['Sales'],fcst_HoltW['Holt04'])
# Out:
# 17.31403001584074

# %%
model03_fit = ExponentialSmoothing(np.asarray(Champagne['Sales']),  seasonal_periods=12, trend='add',seasonal='add').fit(smoothing_slope = 0.01, smoothing_seasonal=0.55, smoothing_level = 0.25, optimized=False)

# %%
model03_fit.forecast(24)
# Out:
# array([ 7082.8422897 , 10207.96732364, 13087.02591778,  4283.63086162,
#         3555.49470787,  4507.96873147,  4741.40984969,  4689.49692168,
#         5191.17982196,  4504.62152108,  1820.66201425,  6234.34437786,
#         7370.26568775, 10495.39072168, 13374.44931582,  4571.05425967,
#         3842.91810592,  4795.39212952,  5028.83324774,  4976.92031972,
#         5478.60322001,  4792.04491913,  2108.08541229,  6521.76777591])

# %%
model044_fit = ExponentialSmoothing(np.asarray(Champagne['Sales']),  seasonal_periods=12, trend='add',seasonal='add').fit(smoothing_slope = 0.086, smoothing_seasonal=0.82, smoothing_level = 0.086, optimized=False)

# %%
model044_fit.forecast(24)
# Out:
# array([ 6973.4041234 ,  9946.82017608, 12873.59068514,  4423.77499064,
#         3643.21947902,  4647.32386006,  4870.60957207,  4753.77049031,
#         5335.1835093 ,  4428.17621941,  1569.45126347,  6055.55806515,
#         7098.61371467, 10072.02976734, 12998.8002764 ,  4548.9845819 ,
#         3768.42907029,  4772.53345132,  4995.81916333,  4878.98008157,
#         5460.39310056,  4553.38581067,  1694.66085473,  6180.76765642])
